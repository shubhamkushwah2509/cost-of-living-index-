# %% [markdown]
# # Project on Analysing  cost of living in various cities of usa

# %% [markdown]
# # Introduction

# %% [markdown]
# A cost of living index measures the relative cost of goods and services in different cities or countries. It is calculated by comparing the cost of a basket of goods and services, such as food, housing, transportation, and healthcare, in different locations. The index is usually expressed in bar chart along with different parametre , The cost of living index can be used to compare the affordability of different cities or countries and can be a useful tool for budgeting and financial planning.

# %% [markdown]
# an analysis is done to determine cost of living in various cites of usa to manage their expences along with aware cost of daily usage things
# such as food , appartment rent , transportation and healthcare in different location

# %% [markdown]
# # import libraries

# %%
import pandas as pd     
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("global_index_clean.csv")    # we have sucessfully load data set
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      city      country    x1     x2    x3    x4  \
# 0             0           0     Delhi        India  4.90  22.04  4.28  1.84
# 1             1           1  Shanghai        China  5.59  40.51  5.59  1.12
# 2             2           2   Jakarta    Indonesia  2.54  22.25  3.50  2.02
# 3             3           3    Manila  Philippines  3.54  27.40  3.54  1.24
# 4             4           4     Seoul  South Korea  7.16  52.77  6.03  3.02
#
#      x5    x6  ...     x47      x48     x49      x50      x51       x52  \
# 0  3.67  1.78  ...   36.26   223.87  133.38   596.16   325.82   2619.46
# 1  4.19  3.96  ...  121.19  1080.07  564.30  2972.57  1532.23  17333.09
# 2  3.18  2.19  ...   80.32   482.85  270.15  1117.69   584.37   2694.05
# 3  1.90  2.91  ...   61.82   559.52  281.78  1754.40   684.81   3536.04
# 4  4.52  3.86  ...  108.30   809.83  583.60  2621.05  1683.74  21847.94
#
#         x53      x54   x55  data_quality
# ...

# %%
df_usa=df[df['country']=='United States']  # we fetch data for analysis  of united state

# %%
df_usa
# Out:
#       Unnamed: 0.1  Unnamed: 0          city        country    x1      x2  \
# 20              20          20      New York  United States  25.0  100.00
# 32              32          32   Los Angeles  United States  20.0   87.09
# 45              45          45       Chicago  United States  20.0   80.00
# 73              73          73         Miami  United States  20.0  100.00
# 86              86          86  Philadelphia  United States  19.0   67.50
# ...            ...         ...           ...            ...   ...     ...
# 4794          4849        4849        Hilton  United States  10.0   65.00
# 4795          4850        4850      Flanders  United States  15.0   60.00
# 4796          4851        4851  Wrightsville  United States  25.0   45.00
# 4802          4857        4857      Bulverde  United States   0.0   45.00
# 4803          4858        4858          Iola  United States   9.5   35.00
#
#          x3   x4    x5    x6  ...     x47      x48      x49      x50      x51  \
# ...

# %%
df_usa = df_usa.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])  # delete unwanted  columns

# %%
df_usa
# Out:
#               city        country    x1      x2     x3   x4    x5    x6    x7  \
# 20        New York  United States  25.0  100.00  10.00  8.0  10.0  5.38  2.72
# 32     Los Angeles  United States  20.0   87.09  10.00  7.5   8.0  4.95  2.70
# 45         Chicago  United States  20.0   80.00   9.50  5.5   6.5  4.70  2.29
# 73           Miami  United States  20.0  100.00   9.50  6.0   8.0  4.64  2.19
# 86    Philadelphia  United States  19.0   67.50   8.00  6.0   8.0  4.60  2.33
# ...            ...            ...   ...     ...    ...  ...   ...   ...   ...
# 4794        Hilton  United States  10.0   65.00   9.00  5.5   6.0  4.00  1.62
# 4795      Flanders  United States  15.0   60.00   7.75  4.0   6.0  3.83  2.00
# 4796  Wrightsville  United States  25.0   45.00  11.00  5.0   8.0  3.50  1.95
# 4802      Bulverde  United States   0.0   45.00   8.00  5.0   3.0  4.00  0.00
# 4803          Iola  United States   9.5   35.00   9.00  2.0   0.0  5.50  1.64
#
# ...

# %% [markdown]
# from above we find 58 columns and 1069 attribute this data set is cleaned which we have done in last analysis and also it doesnot present any null value so we use this dataset for further analysis

# %% [markdown]
# # column refrences

# %% [raw]
# city	Name of the city
# country	Name of the country
# x1	Meal, Inexpensive Restaurant (USD)
# x2	Meal for 2 People, Mid-range Restaurant, Three-course (USD)
# x3	McMeal at McDonalds (or Equivalent Combo Meal) (USD)
# x4	Domestic Beer (0.5 liter draught, in restaurants) (USD)
# x5	Imported Beer (0.33 liter bottle, in restaurants) (USD)
# x6	Cappuccino (regular, in restaurants) (USD)
# x7	Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)
# x8	Water (0.33 liter bottle, in restaurants) (USD)
# x9	Milk (regular), (1 liter) (USD)
# x10	Loaf of Fresh White Bread (500g) (USD)
# x11	Rice (white), (1kg) (USD)
# x12	Eggs (regular) (12) (USD)
# x13	Local Cheese (1kg) (USD)
# x14	Chicken Fillets (1kg) (USD)
# x15	Beef Round (1kg) (or Equivalent Back Leg Red Meat) (USD)
# x16	Apples (1kg) (USD)
# x17	Banana (1kg) (USD)
# x18	Oranges (1kg) (USD)
# x19	Tomato (1kg) (USD)
# x20	Potato (1kg) (USD)
# x21	Onion (1kg) (USD)
# x22	Lettuce (1 head) (USD)
# x23	Water (1.5 liter bottle, at the market) (USD)
# x24	Bottle of Wine (Mid-Range, at the market) (USD)
# x25	Domestic Beer (0.5 liter bottle, at the market) (USD)
# x26	Imported Beer (0.33 liter bottle, at the market) (USD)
# x27	Cigarettes 20 Pack (Marlboro) (USD)
# x28	One-way Ticket (Local Transport) (USD)
# x29	Monthly Pass (Regular Price) (USD)
# x30	Taxi Start (Normal Tariff) (USD)
# x31	Taxi 1km (Normal Tariff) (USD)
# x32	Taxi 1hour Waiting (Normal Tariff) (USD)
# x33	Gasoline (1 liter) (USD)
# x34	Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car) (USD)
# x35	Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car) (USD)
# x36	Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment (USD)
# x37	1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans) (USD)
# x38	Internet (60 Mbps or More, Unlimited Data, Cable/ADSL) (USD)
# x39	Fitness Club, Monthly Fee for 1 Adult (USD)
# x40	Tennis Court Rent (1 Hour on Weekend) (USD)
# x41	Cinema, International Release, 1 Seat (USD)
# x42	Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)
# x43	International Primary School, Yearly for 1 Child (USD)
# x44	1 Pair of Jeans (Levis 501 Or Similar) (USD)
# x45	1 Summer Dress in a Chain Store (Zara, H&M, …) (USD)
# x46	1 Pair of Nike Running Shoes (Mid-Range) (USD)
# x47	1 Pair of Men Leather Business Shoes (USD)
# x48	Apartment (1 bedroom) in City Centre (USD)
# x49	Apartment (1 bedroom) Outside of Centre (USD)
# x50	Apartment (3 bedrooms) in City Centre (USD)
# x51	Apartment (3 bedrooms) Outside of Centre (USD)
# x52	Price per Square Meter to Buy Apartment in City Centre (USD)
# x53	Price per Square Meter to Buy Apartment Outside of Centre (USD)
# x54	Average Monthly Net Salary (After Tax) (USD)
# x55	Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate

# %%
df_usa.describe()  # to get all numerical measurement details
# Out:
#                 x1           x2          x3           x4           x5  \
# count  1069.000000  1069.000000  1069.00000  1069.000000  1069.000000
# mean     14.115772    53.796268     8.04537     4.325622     5.614892
# std       8.879853    27.283078     2.26543     2.317644     2.129057
# min       0.000000     0.000000     0.00000     0.000000     0.000000
# 25%      10.500000    45.000000     7.25000     3.500000     5.000000
# 50%      15.000000    56.500000     8.00000     4.750000     6.000000
# 75%      19.000000    70.000000     9.00000     6.000000     7.000000
# max      55.000000   175.000000    15.00000    15.000000    15.000000
#
#                 x6           x7           x8           x9          x10  ...  \
# count  1069.000000  1069.000000  1069.000000  1069.000000  1069.000000  ...
# mean      4.167007     1.769420     1.546127     0.819710     2.496539  ...
# std       1.314855     1.024435     0.531931     0.443989     1.477970  ...
# ...

# %%
df_usa['x54'].describe()  # for measurement of any specfic column
# Out:
# count    1069.000000
# mean     2311.616782
# std      2245.388439
# min         0.000000
# 25%         0.000000
# 50%      2543.000000
# 75%      4083.330000
# max      9000.000000
# Name: x54, dtype: float64

# %% [markdown]
# df.describe() is used to for mathematical calculation like count , mean stranded deviation min value max value etc

# %% [markdown]
# # Conclusion

# %% [markdown]
# from above mathematical calculations we get some usefull information
#
# from above we find that avg cost in  expensive restaurent (x1)  is 14 usd
#
# avg cost of beer in usa is  4.32 usd
#
# avg cost of water bottle in resturent is 1.54 usd
#
# avg cost of milk (1 liter ) is  3.16 usd
#
# avg cost of rice (1 kg ) is 3.85 usd
#
# avg cost of 12 egg is 3.5 usd
#
# avg cost of groceries is 4.3 usd
#
# avg cost of bus pass monthly is 28.13 usd
#
# avg cost of (Electricity, Heating, Cooling, Water, Garbage) monthly  is 165 usd
#
# avg cost of internet monthly is 66.17 usd
#
# avg cost of fitness club is 25.7 usd
#
# avg cost of Apartment (1 bedroom) in City Centre is 1000 usd
# for 3 bedroom is 1600 usd
#
# Average Monthly Net Salary (After Tax) is 2400 usd
#
# from this analysis we conclude that 50% of sallery spend on rent of apartment for bechlor and we get major expense in rent so we can determine most expensive city and most affordable city on basis of appartment rent

# %% [markdown]
# # 1:- find the city where  restautrent is expensive  and also find the cities where restaurent cost in avg price

# %%
df_x1=df_usa.sort_values(by=['x1'],ascending =False).head(20)  # to sort the data in desending order

# %%
plt.bar(df_x1['city'],df_x1['x1'])    #plotting bar graph 
plt.xticks(rotation='vertical')
plt.title("Most expensive city")
plt.xlabel("city")
plt.ylabel("cost of rasturent in usd")
plt.show()

# %%
df_avgx1=df_usa[df_usa['x1']<14].head(50)  # to find most affordable city where resturent cost in budget
df_avgx1
# Out:
#                city        country     x1      x2     x3    x4    x5    x6  \
# 268       Cleveland  United States  12.00   70.50   8.50  5.75  6.99  4.42
# 279       Manhattan  United States  12.00   45.00   7.50  3.50  5.50  4.00
# 567   Oklahoma City  United States   9.99   45.00   8.00  3.00  6.00  4.13
# 589      Fort Worth  United States  12.00   60.00   8.14  4.00  6.50  4.71
# 621         El Paso  United States  12.00   41.25   7.50  3.75  5.00  3.93
# 629         McAllen  United States  12.00   55.00   6.50  5.00  5.99  4.50
# 660          Dayton  United States   8.00   54.00   7.50  3.25  6.00  3.79
# 696           Tulsa  United States  13.25   48.00   8.00  4.00  5.00  4.50
# 738     Springfield  United States  10.00   47.50   8.50  5.00  6.00  3.96
# 775          Albany  United States  13.50   65.00   9.00  5.00  6.00  3.62
# 785           Ogden  United States  11.00   40.00   7.00  3.00  4.50  4.80
# ...

# %%
plt.figure(figsize=(15,8))
plt.bar(df_avgx1['city'],df_avgx1['x1'])   # plotting bar graph of most affordable city
plt.xticks(rotation='vertical')
plt.title("Most affordable city")
plt.xlabel("city")
plt.ylabel("cost of rasturent in usd")
plt.show()

# %% [markdown]
# from above we find list of most affordable city of usa
#
# Conclusion :- From above, we have get the the plot of the most expensive city and most affordable city in respect of restaurent we can clearly see that lorain city is most expensive with cost 55 usd and most affordable city are cleveland , tempe , Hayward with cost less then avg cost which is 14 usd.
#
# Conclusion :- Hence we have successfully visualize the required columns of the given dataset and we have got the idea of cost of restaurent present in different city.

# %% [markdown]
# # 2:- find the most high paying cities where salleries is maximum

# %%
df_x54=df_usa.sort_values(by=['x54'],ascending =False)  # sorting data in desending order 
df_x54
# Out:
#                    city        country    x1    x2     x3    x4    x5    x6  \
# 4349  Bainbridge Island  United States  25.0  65.0   9.65  5.00  8.25  5.28
# 3022             Elmont  United States  20.0  72.5  10.00  6.25  6.50  4.50
# 2984          Annapolis  United States  20.0  40.0   8.00  5.00  6.00  4.39
# 3548      Newport Beach  United States  20.0  95.0   8.00  9.00  6.00  4.05
# 3089     East Palo Alto  United States  17.5  90.0   8.00  7.00  7.00  4.47
# ...                 ...            ...   ...   ...    ...   ...   ...   ...
# 3852       Grand Island  United States  11.5  56.0   9.62  4.38  6.00  4.83
# 3849             Apopka  United States  20.0  45.0   9.00  5.00  5.00  4.57
# 3848      Pinellas Park  United States   0.0   0.0   6.00  0.00  8.00  5.99
# 3845       Williamsport  United States   0.0  65.0   8.00  5.75  4.00  5.00
# 3987            Lombard  United States   0.0  40.0   8.50  5.00  7.00  4.83
#
# ...

# %%
df_avgx54=df_x54[df_usa['x54']>6000]  # finding most highest paying city
df_avgx54
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2980\3007216400.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_avgx54=df_x54[df_usa['x54']>6000]  # finding most highest paying city
#                        city        country     x1      x2     x3    x4     x5  \
# 4349      Bainbridge Island  United States  25.00   65.00   9.65  5.00   8.25
# 3022                 Elmont  United States  20.00   72.50  10.00  6.25   6.50
# 2984              Annapolis  United States  20.00   40.00   8.00  5.00   6.00
# 3548          Newport Beach  United States  20.00   95.00   8.00  9.00   6.00
# 3089         East Palo Alto  United States  17.50   90.00   8.00  7.00   7.00
# 3784            Des Plaines  United States  20.00   80.00   9.00  5.00   6.50
# 3612                 Conway  United States   0.00   70.00   8.75  3.50   4.50
# 3043            Foster City  United States  17.50   55.00   7.50  0.00   0.00
# ...

# %%
plt.figure(figsize=(15,8))
plt.bar(df_avgx54['city'],df_avgx54['x54'])   # plotting graph 
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Conclusion:-
#
# from above we find the most high paying cities in which Bainbridge island is the most highest paying city with 9000 usd and greatfall on least with avg sallery of 1000 usd

# %% [markdown]
# # find the citiy where grocraies is expensive also find city where grocries are affordable

# %%
df_usa.to_csv("cost of living in usa.csv")  # we export data into csv to merge some columns

# %%
df=pd.read_csv("cost of living in usa.csv")  # loading data updated dataset
df
# Out:
#       Unnamed: 0          city        country    x1      x2     x3   x4    x5  \
# 0             20      New York  United States  25.0  100.00  10.00  8.0  10.0
# 1             32   Los Angeles  United States  20.0   87.09  10.00  7.5   8.0
# 2             45       Chicago  United States  20.0   80.00   9.50  5.5   6.5
# 3             73         Miami  United States  20.0  100.00   9.50  6.0   8.0
# 4             86  Philadelphia  United States  19.0   67.50   8.00  6.0   8.0
# ...          ...           ...            ...   ...     ...    ...  ...   ...
# 1064        4794        Hilton  United States  10.0   65.00   9.00  5.5   6.0
# 1065        4795      Flanders  United States  15.0   60.00   7.75  4.0   6.0
# 1066        4796  Wrightsville  United States  25.0   45.00  11.00  5.0   8.0
# 1067        4802      Bulverde  United States   0.0   45.00   8.00  5.0   3.0
# 1068        4803          Iola  United States   9.5   35.00   9.00  2.0   0.0
#
# ...

# %%
df['xavg'].describe()   # we added new column "xavg" which is average of all groceries
# Out:
# count    1069.000000
# mean        4.527970
# std         1.725968
# min         0.000000
# 25%         3.700000
# 50%         4.800000
# 75%         5.600000
# max        10.700000
# Name: xavg, dtype: float64

# %%
dfsort=df.sort_values(by=['xavg'],ascending =False)  # sorting data into desending order 
dfsort
# Out:
#       Unnamed: 0                 city        country    x1     x2    x3  \
# 898         4408               Gallup  United States   0.0   60.0  15.0
# 233         1868       Fredericksburg  United States  30.0  105.0   8.0
# 429         3008  South Miami Heights  United States  50.0   25.0  11.5
# 609         3685     Saratoga Springs  United States   9.5   85.0  12.5
# 1052        4762    North Springfield  United States  30.0   50.0   9.5
# ...          ...                  ...            ...   ...    ...   ...
# 777         4115              Commack  United States   0.0  100.0  10.0
# 770         4092               Groton  United States  25.0   55.0   9.5
# 522         3462           Rio Rancho  United States   0.0    0.0   0.0
# 749         4042          Catonsville  United States  35.0   60.0  12.0
# 832         4248        East Fishkill  United States  25.0  100.0   7.0
#
#          x4     x5     x6    x7  ...    x47     x48     x49     x50     x51  \
# ...

# %%
dfsort1=dfsort.head(20)

# %%
plt.bar(dfsort1['city'],dfsort1['xavg'])  # plotting bargraph
plt.xticks(rotation='vertical')
plt.xlabel(" most expensive city")
plt.ylabel("cost of groceries")
plt.title("costly city of usa ")
plt.show()

# %%
dfavg=dfsort[dfsort['xavg']<4].head(20)

# %%
plt.bar(dfavg['city'],dfavg['xavg'])
plt.xticks(rotation='vertical')
plt.xlabel("city")
plt.ylabel("cost of groceries")
plt.title("most affordable city of usa ")
plt.show()

# %% [markdown]
# conclusion :-
#
# from above we find gallup is city where groceries are expensive with scale 10.6 and havelock city is least expensive with scale 0.7

# %% [markdown]
# # find most epensive  city in usa also find most affordable city in usa

# %%
dfsort=df.sort_values(by=['x54'],ascending =False)

# %%
dfappartment=dfsort.head(10)

# %%
plt.bar(dfappartment['city'],dfappartment['x54'])
plt.xticks(rotation='vertical')
plt.xlabel("city")
plt.ylabel("cost of apartment")
plt.title("most expensive city of usa ")
plt.show()

# %%
dfavgcost=df[df['x54']<2300]
dfavgcost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9264\2875864206.py in <module>
# ----> 1 dfavgcost=df[df['x54']<2300]
#       2 dfavgcost
#
# NameError: name 'df' is not defined

# %%
dfavg=dfavgcost.sort_values(by='x54',ascending=False).head(20)

# %%
plt.bar(dfavg['city'],dfavg['x54'])
plt.xticks(rotation='vertical')
plt.xlabel("city")
plt.ylabel("cost of appartment")
plt.title("most affordable city of usa")
plt.show()

# %% [markdown]
# # Conclusion of Analysis

# %% [markdown]
# conclusion:-
#
# from above we find that banbridge island is most expensive city in usa where major expenses in rent in usa so we can identify expensive city affordable city in respect to appartment rent  and johnson , biloxi , youngstown are some most affordable city

# %% [markdown]
#   The main Objective of this project was to Analyze and visualize the various factors which have contributed in the analysing cost of living in usa . These type of Analysis are very helpful as this type of Analysis can be performed by any Country which can help them in analyzing their cost so that they can improve their decission according to their expenses and budget.

# %% [markdown]
# # Thank you
